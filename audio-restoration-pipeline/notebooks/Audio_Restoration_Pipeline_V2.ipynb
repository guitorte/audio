# %% [markdown]
# # 🎵 Pipeline Profissional de Restauração de Áudio - V2.0
#
# ## ⚡ Versão Avançada com IA e Interface Visual
#
# ### 🎯 Recursos:
# - ✅ **Interface Visual Interativa** - Configure com widgets visuais
# - ✅ **Auto-Configuração Inteligente** - IA analisa e sugere configurações
# - ✅ **Processamento Avançado** - 15+ processadores profissionais
# - ✅ **Separação de Stems** - Demucs + processamento individual
# - ✅ **Análise Detalhada** - Relatórios completos com visualizações
# - ✅ **Batch Processing** - Processe múltiplos arquivos
#
# ---
#
# ### 📋 Modos de Uso:
# 1. **🎛️ Modo Visual** - Interface com widgets (recomendado para iniciantes)
# 2. **🤖 Modo Auto** - IA decide tudo (recomendado para melhor resultado)
# 3. **⚙️ Modo Manual** - Controle total (para usuários avançados)
#
# ---

# %% [markdown]
# ## 📦 1. Instalação de Dependências
#
# Execute uma vez no início da sessão.

# %%
# %%capture

# Dependências principais
# !pip install librosa soundfile scipy matplotlib numpy
# !pip install noisereduce

# Interface visual
# !pip install ipywidgets

# Demucs (opcional - descomente se quiser usar)
# !pip install demucs

print("✓ Dependências instaladas!")

# %% [markdown]
# ## 💾 2. Montar Google Drive e Verificar GPU

# %%
from google.colab import drive
import torch

# Montar Drive
drive.mount('/content/drive')

# Definir caminhos
AUDIO_INPUT_DIR = '/content/drive/MyDrive/00-restore'
AUDIO_OUTPUT_DIR = '/content/drive/MyDrive/00-restore/restored_output'

print(f"✓ Drive montado")
print(f"📁 Entrada: {AUDIO_INPUT_DIR}")
print(f"📁 Saída: {AUDIO_OUTPUT_DIR}")

# Verificar GPU
print("\n" + "="*60)
if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    vram = torch.cuda.get_device_properties(0).total_memory / 1024**3
    print(f"⚡ GPU DISPONÍVEL: {gpu_name}")
    print(f"   VRAM: {vram:.1f} GB")
    print("   💡 Demucs será MUITO mais rápido!")
else:
    print("⚠️ GPU NÃO DISPONÍVEL")
    print("   Para ativar: Runtime → Change runtime type → GPU")
    print("   ⏳ Demucs será lento sem GPU")
print("="*60)

# %% [markdown]
# ## 📥 3. Baixar Pipeline do GitHub

# %%
import os

# Remover versão antiga (se existir)
# !rm -rf /content/audio-pipeline-repo

# Clonar branch correto com todas as funcionalidades
# !git clone -b claude/audio-restoration-pipeline-gAFxk \
  https://github.com/guitorte/musicas.git \
  /content/audio-pipeline-repo

print("\n✓ Pipeline baixado com sucesso!")
print("✓ Versão: 2.0 - Advanced Features")

# %% [markdown]
# ## 🔧 4. Importar Módulos

# %%
import sys
import warnings
warnings.filterwarnings('ignore')

# Adicionar ao path
sys.path.insert(0, '/content/audio-pipeline-repo/audio-restoration-pipeline')

# Importar módulos principais
from modules import AudioRestorationPipeline
from modules import SpectralAnalyzer

# Importar funcionalidades avançadas
from modules import AdvancedAudioProcessor
from modules import auto_configure
from modules import create_quick_config

# Utilitários
import os
import glob
import json
from pathlib import Path
from IPython.display import Audio, Image, display, HTML

print("✓ Módulos importados com sucesso!")
print("\n📦 Funcionalidades disponíveis:")
print("  • AudioRestorationPipeline - Pipeline principal")
print("  • SpectralAnalyzer - Análise de áudio")
print("  • AdvancedAudioProcessor - Processamento avançado")
print("  • auto_configure - Auto-configuração IA")
print("  • create_quick_config - Interface visual")

# %% [markdown]
# ## 📂 5. Listar Arquivos de Áudio

# %%
# Buscar arquivos MP3 e WAV
audio_files = []
audio_files.extend(glob.glob(os.path.join(AUDIO_INPUT_DIR, '*.mp3')))
audio_files.extend(glob.glob(os.path.join(AUDIO_INPUT_DIR, '*.wav')))
audio_files.extend(glob.glob(os.path.join(AUDIO_INPUT_DIR, '*.MP3')))
audio_files.extend(glob.glob(os.path.join(AUDIO_INPUT_DIR, '*.WAV')))

audio_files = sorted(set(audio_files))

print(f"✓ Encontrados {len(audio_files)} arquivos de áudio\n")
print("="*70)

for i, file in enumerate(audio_files, 1):
    file_size_mb = os.path.getsize(file) / (1024 * 1024)
    file_name = Path(file).name
    print(f"{i:2d}. {file_name[:50]:50s} ({file_size_mb:6.2f} MB)")

print("="*70)

if not audio_files:
    print(f"\n⚠️ AVISO: Nenhum arquivo encontrado em {AUDIO_INPUT_DIR}")
    print("Verifique se o caminho está correto!")

# %% [markdown]
# ## 🚀 6. Inicializar Pipeline

# %%
# Criar diretório de saída
os.makedirs(AUDIO_OUTPUT_DIR, exist_ok=True)

# Inicializar pipeline
pipeline = AudioRestorationPipeline(
    sr=44100,
    output_base_dir=AUDIO_OUTPUT_DIR,
    log_dir=os.path.join(AUDIO_OUTPUT_DIR, 'logs')
)

print("✓ Pipeline inicializado e pronto para uso!")
print("\n📊 Configuração:")
print(f"  Sample Rate: 44100 Hz")
print(f"  Output: {AUDIO_OUTPUT_DIR}")

# %% [markdown]
# ---
#
# # 🎯 ESCOLHA SEU MODO DE PROCESSAMENTO
#
# Escolha **UMA** das 3 opções abaixo:
#
# ---

# %% [markdown]
# ## 🎛️ OPÇÃO 1: Interface Visual (Recomendado)
#
# Configure tudo visualmente com sliders e dropdowns!

# %%
# ════════════════════════════════════════════════════════════
# INTERFACE VISUAL INTERATIVA
# ════════════════════════════════════════════════════════════

from modules import create_quick_config

print("🎛️ Criando interface visual...\n")
print("Configure os parâmetros abaixo e clique em 'GERAR CONFIGURAÇÃO'\n")
print("="*70)

# Criar interface
CONFIG = create_quick_config()

print("\n✓ Interface criada!")
print("💡 Configure acima e depois execute a célula de processamento")

# %% [markdown]
# ## 🤖 OPÇÃO 2: Auto-Configuração Inteligente (Melhor Resultado)
#
# Deixe a IA analisar e configurar automaticamente!

# %%
# ════════════════════════════════════════════════════════════
# AUTO-CONFIGURAÇÃO BASEADA EM IA
# ════════════════════════════════════════════════════════════

from modules import auto_configure, SpectralAnalyzer

# Selecionar arquivo para análise
if audio_files:
    test_file = audio_files[0]  # Mudar índice para outro arquivo
    
    print(f"🔍 Analisando: {Path(test_file).name}")
    print("="*70)
    
    # Analisar áudio
    analyzer = SpectralAnalyzer()
    analysis = analyzer.analyze_audio(test_file)
    
    # Gerar configuração inteligente
    CONFIG = auto_configure(analysis, verbose=True)
    
    print("\n✓ Configuração inteligente gerada!")
    print("💡 Execute a célula de processamento para aplicar")
else:
    print("⚠️ Nenhum arquivo encontrado para análise")

# %% [markdown]
# ## ⚙️ OPÇÃO 3: Configuração Manual (Controle Total)
#
# Defina cada parâmetro manualmente.

# %%
# ════════════════════════════════════════════════════════════
# CONFIGURAÇÃO MANUAL PERSONALIZADA
# ════════════════════════════════════════════════════════════

# Escolha um perfil base ou crie o seu

# ────────────────────────────────────────────────────────────
# PERFIL 1: Padrão
# ────────────────────────────────────────────────────────────
CONFIG_PADRAO = {
    'remove_clicks': True,
    'reduce_noise': True,
    'noise_reduction_strength': 0.6,
    'restore_frequencies': True,
    'freq_restoration_method': 'harmonic_synthesis',
    'enhance_bass': False,
    'psychoacoustic_enhancement': True,
    'separate_stems': False,
    'target_lufs': -14.0,
    'master_eq': {'bass': 0.0, 'mid': 0.0, 'presence': 1.0, 'treble': 0.8},
    'add_presence': True
}

# ────────────────────────────────────────────────────────────
# PERFIL 2: Demucs (Alta Qualidade)
# ────────────────────────────────────────────────────────────
CONFIG_DEMUCS = {
    'remove_clicks': True,
    'reduce_noise': True,
    'noise_reduction_strength': 0.6,
    'restore_frequencies': True,
    'freq_restoration_method': 'harmonic_synthesis',
    'enhance_bass': False,
    'psychoacoustic_enhancement': True,
    'separate_stems': True,
    'stem_separation_model': 'demucs',
    'process_stems_individually': True,
    'target_lufs': -14.0,
    'master_eq': {'bass': 0.0, 'mid': 0.0, 'presence': 2.0, 'treble': 2.5},
    'add_presence': True
}

# ────────────────────────────────────────────────────────────
# PERFIL 3: Agressivo (Áudio Degradado)
# ────────────────────────────────────────────────────────────
CONFIG_AGRESSIVO = {
    'remove_clicks': True,
    'reduce_noise': True,
    'noise_reduction_strength': 0.85,
    'restore_frequencies': True,
    'freq_restoration_method': 'spectral_extension',
    'enhance_bass': True,
    'bass_enhancement_amount': 1.5,
    'psychoacoustic_enhancement': True,
    'separate_stems': False,
    'target_lufs': -14.0,
    'master_eq': {'bass': 0.5, 'mid': -1.0, 'presence': 3.0, 'treble': 3.5},
    'add_presence': True
}

# ────────────────────────────────────────────────────────────
# PERFIL 4: Suave (Áudio Já Bom)
# ────────────────────────────────────────────────────────────
CONFIG_SUAVE = {
    'remove_clicks': True,
    'reduce_noise': False,
    'noise_reduction_strength': 0.0,
    'restore_frequencies': True,
    'freq_restoration_method': 'harmonic_synthesis',
    'enhance_bass': False,
    'psychoacoustic_enhancement': True,
    'separate_stems': False,
    'target_lufs': -14.0,
    'master_eq': {'bass': 0.0, 'mid': 0.0, 'presence': 0.5, 'treble': 0.3},
    'add_presence': False
}

# ════════════════════════════════════════════════════════════
# SELECIONE O PERFIL AQUI:
# ════════════════════════════════════════════════════════════
CONFIG = CONFIG_DEMUCS  # ⭐ Mude para outro perfil se quiser

print("✓ Configuração manual selecionada")
print("\nPerfil ativo:")
print(json.dumps(CONFIG, indent=2))

# %% [markdown]
# ---
#
# # ▶️ PROCESSAMENTO
#
# ---

# %% [markdown]
# ## 🎯 7. Processar Arquivo Individual (Teste)

# %%
# ════════════════════════════════════════════════════════════
# PROCESSAMENTO DE ARQUIVO ÚNICO
# ════════════════════════════════════════════════════════════

if audio_files:
    # Selecionar arquivo (mude o índice se quiser outro)
    test_file = audio_files[0]
    
    print(f"🎵 Processando: {Path(test_file).name}")
    print("="*70)
    
    # Avisos de tempo
    if CONFIG.get('separate_stems') and CONFIG.get('stem_separation_model') == 'demucs':
        print("\n⏳ ATENÇÃO: Demucs ativado")
        print("   • Com GPU: ~5-10 minutos")
        print("   • Sem GPU: ~15-30 minutos")
        print("="*70 + "\n")
    
    # Processar
    result = pipeline.process_audio(
        test_file,
        config=CONFIG
    )
    
    # Resultado
    print("\n" + "="*70)
    print("✓ PROCESSAMENTO COMPLETO!")
    print("="*70)
    
    print(f"\n📁 Pasta de saída: {result['output_dir']}")
    print(f"\n🎵 Arquivo final masterizado:")
    print(f"   {Path(result['stages']['mastering']['output']).name}")
    
    # Mostrar stems se foram separados
    if 'stem_separation' in result['stages']:
        stems = result['stages']['stem_separation']
        print(f"\n🎸 Stems separados ({len(stems)} arquivos):")
        for stem_name in stems:
            print(f"   • {stem_name}")
    
    # Armazenar resultado para próximas células
    LAST_RESULT = result
    LAST_FILE = test_file
    
    print("\n💡 Execute a próxima célula para ver análise e comparação")
    
else:
    print("⚠️ Nenhum arquivo para processar")

# %% [markdown]
# ## 📊 8. Análise Detalhada e Comparação

# %%
# ════════════════════════════════════════════════════════════
# ANÁLISE E VISUALIZAÇÃO
# ════════════════════════════════════════════════════════════

if 'LAST_RESULT' in globals():
    result = LAST_RESULT
    
    # ────────────────────────────────────────────────────────
    # 1. VISUALIZAÇÃO ESPECTRAL
    # ────────────────────────────────────────────────────────
    viz_path = os.path.join(result['output_dir'], 'analysis_visualization.png')
    if os.path.exists(viz_path):
        print("📊 ANÁLISE ESPECTRAL DO ORIGINAL")
        print("="*70)
        display(Image(filename=viz_path))
    
    # ────────────────────────────────────────────────────────
    # 2. MÉTRICAS E RECOMENDAÇÕES
    # ────────────────────────────────────────────────────────
    analysis_path = os.path.join(result['output_dir'], 'analysis.json')
    if os.path.exists(analysis_path):
        with open(analysis_path, 'r') as f:
            analysis = json.load(f)
        
        print("\n📈 MÉTRICAS DO ÁUDIO ORIGINAL")
        print("="*70)
        print(f"Duração: {analysis['duration']:.2f}s")
        print(f"Sample Rate: {analysis['sample_rate']} Hz")
        print(f"SNR (Signal-to-Noise): {analysis['noise_profile']['snr_db']:.1f} dB")
        print(f"LUFS estimado: {analysis['dynamic_range']['lufs_estimate']:.1f}")
        print(f"Peak: {analysis['dynamic_range']['peak_amplitude']:.3f}")
        print(f"Crest Factor: {analysis['dynamic_range']['crest_factor']:.2f}")
        
        if analysis['clipping_detection']['has_clipping']:
            print(f"⚠️ Clipping: {analysis['clipping_detection']['clip_percentage']:.2f}%")
        
        if analysis['frequency_analysis']['high_freq_loss']:
            print(f"⚠️ Corte de frequências em: {analysis['frequency_analysis']['high_freq_cutoff']:.0f} Hz")
        
        print("\n💡 RECOMENDAÇÕES DA ANÁLISE")
        print("="*70)
        if analysis.get('recommendations'):
            for rec in analysis['recommendations']:
                emoji_map = {'high': '🔴', 'medium': '🟡', 'low': '🟢'}
                emoji = emoji_map.get(rec['severity'], '⚪')
                print(f"{emoji} [{rec['severity'].upper()}] {rec['message']}")
        else:
            print("✓ Nenhum problema crítico detectado")
    
    # ────────────────────────────────────────────────────────
    # 3. COMPARAÇÃO ANTES/DEPOIS
    # ────────────────────────────────────────────────────────
    print("\n\n🎧 COMPARAÇÃO: ORIGINAL vs PROCESSADO")
    print("="*70)
    print("\n🔊 ORIGINAL:")
    display(Audio(LAST_FILE))
    
    print("\n🎵 PROCESSADO (MASTERIZADO):")
    display(Audio(result['stages']['mastering']['output']))
    
    # ────────────────────────────────────────────────────────
    # 4. STEMS (se separados)
    # ────────────────────────────────────────────────────────
    if 'stem_separation' in result['stages']:
        print("\n\n🎸 STEMS SEPARADOS")
        print("="*70)
        print("Ouça cada componente individualmente:\n")
        
        stems = result['stages']['stem_separation']
        
        if 'vocals' in stems:
            print("🎤 VOCAIS:")
            display(Audio(stems['vocals']))
        
        if 'drums' in stems:
            print("\n🥁 BATERIA:")
            display(Audio(stems['drums']))
        
        if 'bass' in stems:
            print("\n🎸 BAIXO:")
            display(Audio(stems['bass']))
        
        if 'other' in stems:
            print("\n🎹 OUTROS:")
            display(Audio(stems['other']))

else:
    print("⚠️ Processe um arquivo primeiro (célula anterior)")

# %% [markdown]
# ## 🔄 9. Processamento em Batch (Opcional)
#
# ⚠️ **ATENÇÃO:** Processa TODOS os arquivos. Pode levar horas!

# %%
# ════════════════════════════════════════════════════════════
# PROCESSAMENTO EM BATCH
# ════════════════════════════════════════════════════════════

# Mude para True para processar todos
BATCH_PROCESS = False  # ⚠️ CUIDADO: Pode levar muito tempo

if BATCH_PROCESS and audio_files:
    print(f"🔄 Iniciando batch de {len(audio_files)} arquivos...")
    print("⏳ Isso pode levar MUITO tempo!\n")
    print("="*70)
    
    batch_results = pipeline.batch_process(
        audio_files,
        config=CONFIG
    )
    
    # Resumo
    successful = sum(1 for r in batch_results if 'error' not in r)
    failed = len(batch_results) - successful
    
    print("\n" + "="*70)
    print("✓ BATCH COMPLETO!")
    print("="*70)
    print(f"Sucesso: {successful}/{len(batch_results)}")
    if failed > 0:
        print(f"Falhas: {failed}")
        
elif not BATCH_PROCESS:
    print("⚠️ Batch desabilitado (segurança)")
    print("\nPara processar todos os arquivos:")
    print("1. Mude BATCH_PROCESS = True acima")
    print("2. Execute esta célula novamente")
    print("\n💡 Recomenda-se testar com 1 arquivo primeiro!")
else:
    print("⚠️ Nenhum arquivo para processar")

# %% [markdown]
# ---
#
# # ⚡ PROCESSAMENTO AVANÇADO (Opcional)
#
# Use processadores profissionais adicionais no resultado
#
# ---

# %% [markdown]
# ## 🎛️ 10. Processamento Avançado Extra

# %%
# ════════════════════════════════════════════════════════════
# PROCESSAMENTO AVANÇADO MANUAL
# Aplica processadores profissionais extras ao resultado
# ════════════════════════════════════════════════════════════

if 'LAST_RESULT' in globals():
    import librosa
    import soundfile as sf
    from modules import AdvancedAudioProcessor
    
    print("⚡ Aplicando processamento avançado extra...\n")
    
    # Carregar resultado masterizado
    y_final, sr = librosa.load(LAST_RESULT['stages']['mastering']['output'])
    
    # Inicializar processador avançado
    processor = AdvancedAudioProcessor(sr=sr)
    
    # ────────────────────────────────────────────────────────
    # Escolha os processamentos (comente os que não quiser)
    # ────────────────────────────────────────────────────────
    
    # 1. Compressão Multi-banda
    print("  ✓ Compressão multi-banda...")
    y_final = processor.multiband_compress(y_final, sr)
    
    # 2. De-esser (se tiver vocal)
    # print("  ✓ De-esser...")
    # y_final = processor.de_esser(y_final, sr)
    
    # 3. Exciter Harmônico
    print("  ✓ Exciter harmônico...")
    y_final = processor.harmonic_exciter(y_final, sr, drive=0.2, mix=0.15)
    
    # 4. Alargamento Estéreo
    if len(y_final.shape) > 1:
        print("  ✓ Stereo enhance...")
        y_final = processor.stereo_enhance(y_final, width=1.3, focus_freq=200)
    
    # 5. Transient Shaper (para bateria/percussão)
    # print("  ✓ Transient shaper...")
    # y_final = processor.transient_shaper(y_final, sr, attack_gain=1.2, sustain_gain=0.9)
    
    # Salvar versão com processamento extra
    output_path = os.path.join(
        LAST_RESULT['output_dir'],
        'FINAL_ADVANCED_ENHANCED.wav'
    )
    
    sf.write(
        output_path,
        y_final if len(y_final.shape) == 1 else y_final.T,
        sr
    )
    
    print(f"\n✓ Processamento avançado completo!")
    print(f"✓ Salvo em: {Path(output_path).name}")
    
    # Comparação final
    print("\n" + "="*70)
    print("🎧 COMPARAÇÃO: MASTERIZADO vs ADVANCED ENHANCED")
    print("="*70)
    
    print("\n🎵 MASTERIZADO (pipeline):")
    display(Audio(LAST_RESULT['stages']['mastering']['output']))
    
    print("\n✨ ADVANCED ENHANCED (com processamento extra):")
    display(Audio(output_path))
    
else:
    print("⚠️ Processe um arquivo primeiro")

# %% [markdown]
# ## 📋 11. Auto-EQ Analyzer
#
# Analisa o áudio e sugere correções de EQ automaticamente

# %%
# ════════════════════════════════════════════════════════════
# ANÁLISE AUTOMÁTICA DE EQ
# ════════════════════════════════════════════════════════════

if 'LAST_FILE' in globals():
    import librosa
    from modules import AdvancedAudioProcessor
    
    print("📊 Analisando espectro e sugerindo correções de EQ...\n")
    
    # Carregar áudio
    y, sr = librosa.load(LAST_FILE, sr=44100)
    
    # Analisar
    processor = AdvancedAudioProcessor()
    eq_suggestions = processor.auto_eq_analyzer(y, sr)
    
    print("="*70)
    print("💡 SUGESTÕES DE EQ BASEADAS NA ANÁLISE ESPECTRAL")
    print("="*70)
    print("\nCorreções sugeridas para balancear o espectro:\n")
    
    for band, gain_db in eq_suggestions.items():
        sign = "+" if gain_db > 0 else ""
        
        # Criar barra visual
        bar_length = int(abs(gain_db))
        bar = "█" * bar_length if bar_length > 0 else ""
        
        # Cor baseada em boost/cut
        color = "🟢" if gain_db > 0 else "🔴" if gain_db < 0 else "⚪"
        
        print(f"{color} {band:12s}: {sign}{gain_db:+5.1f} dB {bar}")
    
    print("\n" + "─"*70)
    print("\n💡 Use essas sugestões na configuração 'master_eq':")
    print("\nmaster_eq = {")
    for band, gain in eq_suggestions.items():
        print(f"    '{band}': {gain:.1f},")
    print("}")
    
else:
    print("⚠️ Processe um arquivo primeiro")

# %% [markdown]
# ---
#
# # 💾 UTILITÁRIOS
#
# ---

# %% [markdown]
# ## 💾 12. Download de Resultados

# %%
# ════════════════════════════════════════════════════════════
# DOWNLOAD DE ARQUIVOS PROCESSADOS
# ════════════════════════════════════════════════════════════

from google.colab import files

# Listar arquivos finais
output_files = glob.glob(
    os.path.join(AUDIO_OUTPUT_DIR, '**/*FINAL*.wav'),
    recursive=True
)

if output_files:
    print(f"📦 Encontrados {len(output_files)} arquivos finais:\n")
    print("="*70)
    
    for i, file in enumerate(output_files, 1):
        file_size_mb = os.path.getsize(file) / (1024 * 1024)
        print(f"{i:2d}. {Path(file).name[:50]:50s} ({file_size_mb:6.2f} MB)")
    
    print("="*70)
    print("\n💡 Para fazer download de um arquivo:")
    print("\n# Descomente e ajuste o índice:")
    print("# files.download(output_files[0])  # Baixar o primeiro")
    
    # Descomente a linha abaixo para baixar o primeiro arquivo
    # files.download(output_files[0])
    
else:
    print("⚠️ Nenhum arquivo final encontrado")
    print("Processe arquivos primeiro")

# %% [markdown]
# ## 📝 13. Salvar Configuração Favorita

# %%
# ════════════════════════════════════════════════════════════
# SALVAR CONFIGURAÇÃO NO DRIVE
# ════════════════════════════════════════════════════════════

# Salvar configuração atual
config_save_path = os.path.join(AUDIO_OUTPUT_DIR, 'my_favorite_config.json')

with open(config_save_path, 'w') as f:
    json.dump(CONFIG, f, indent=2)

print(f"✓ Configuração salva em:")
print(f"  {config_save_path}")
print("\n💡 Para carregar depois:")
print("""
with open(config_save_path, 'r') as f:
    CONFIG = json.load(f)
""")

# %% [markdown]
# ## 🔧 14. Verificar Status de Instalação

# %%
# ════════════════════════════════════════════════════════════
# VERIFICAR INSTALAÇÕES E FUNCIONALIDADES
# ════════════════════════════════════════════════════════════

import subprocess
import torch

print("🔍 Verificando instalações...\n")
print("="*70)

# GPU
if torch.cuda.is_available():
    print(f"✓ GPU: {torch.cuda.get_device_name(0)}")
else:
    print("✗ GPU: Não disponível")

# Demucs
try:
    result = subprocess.run(['demucs', '--version'], capture_output=True, text=True)
    print(f"✓ Demucs: Instalado")
except FileNotFoundError:
    print("✗ Demucs: Não instalado (opcional)")
    print("  Para instalar: !pip install demucs")

# Módulos avançados
try:
    from modules import AdvancedAudioProcessor, auto_configure, create_quick_config
    print("✓ Funcionalidades Avançadas: Disponíveis")
    print("  • AdvancedAudioProcessor")
    print("  • auto_configure")
    print("  • create_quick_config")
except ImportError as e:
    print(f"✗ Funcionalidades Avançadas: Erro - {e}")

# Arquivos
print(f"\n✓ Arquivos encontrados: {len(audio_files)}")

print("="*70)
print("\n✓ Verificação completa!")

# %% [markdown]
# ---
#
# ## 📚 Documentação e Ajuda
#
# ### 🔗 Links Úteis:
# - **README.md** - Documentação principal
# - **ADVANCED_FEATURES.md** - Funcionalidades avançadas
# - **Advanced_Usage_Examples.md** - Exemplos práticos
#
# ### 💡 Dicas:
#
# **Para Áudio de BOA Qualidade:**
# - Use perfil "Suave" ou "Padrão"
# - Não use separação de stems
# - EQ suave: presence +0.5, treble +0.3
#
# **Para Áudio DEGRADADO:**
# - Use "Auto-Configuração" (IA decide)
# - Ou perfil "Agressivo"
# - Considere separação de stems
#
# **Para MÁXIMA Qualidade:**
# - Use perfil "Demucs"
# - Certifique-se de ter GPU
# - Aguarde 5-20 minutos
#
# ### ⚙️ Parâmetros Principais:
#
# **LUFS:**
# - `-14.0` = Spotify, YouTube, Apple Music
# - `-16.0` = TV, Rádio, Broadcast
# - `-23.0` = Cinema
#
# **Noise Reduction:**
# - `0.5-0.6` = Suave
# - `0.7-0.8` = Moderado
# - `0.85-0.9` = Agressivo
#
# **EQ:**
# - Valores negativos = Reduzir
# - Valores positivos = Aumentar
# - Range: -6.0 a +6.0 dB
#
# ---
#
# **Pipeline desenvolvido com tecnologias de ponta em processamento de áudio**
#
# 🎵 **Versão 2.0 - Advanced Features** 🚀
#
# ---
